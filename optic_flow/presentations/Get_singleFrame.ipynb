# %%
LOCAL_CLIP = '/path/to/trial15_saccade_6770_8890_annotated.mp4'   # a clip on your computer
_lc = Path(LOCAL_CLIP).expanduser().resolve()
play(_lc)                              # embed it inline (if <= 25 MB)
pdf_from_clip(_lc, 6920, fmt='pdf')    # session frame 6920 -> PDF saved next to the clip
